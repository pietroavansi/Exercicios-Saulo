# %% [markdown]
# <a href="https://colab.research.google.com/github/pietroavansi/Exerc-cios-Saulo-aula-1-/blob/main/aula2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int(input('Digite um número inteiro:'))
if numero > 0:
  print('Positivo')
elif numero < 0:
  print('Negativo')
else:
  print('Zero')
